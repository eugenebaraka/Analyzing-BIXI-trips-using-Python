# %%
#importing required packages to concat csv files and read data

# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
#specifying the path in which the files are located
files = os.path.join('OneDrive-McGill/Desktop/Projects/BIXI/data/', 'OD_*.csv')
#creating a list of loaded files and joining the files into a dataframe
files = glob.glob(files)
bixi_df = pd.concat(map(pd.read_csv, files), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15200/3651642368.py in <module>
#       3 #creating a list of loaded files and joining the files into a dataframe
#       4 files = glob.glob(files)
# ----> 5 bixi_df = pd.concat(map(pd.read_csv, files), ignore_index=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
# ...

# %%
#investigating the sanity of our data after joining the files
bixi.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15200/1853687832.py in <module>
#       1 #investigating the sanity of our data after joining the files
# ----> 2 bixi.shape
#
# NameError: name 'bixi' is not defined

# %% [markdown]
# The output shows that our data has 34,950,766 rows and 8 columns

# %%
bixi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34950766 entries, 0 to 34950765
# Data columns (total 8 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   start_date            object
#  1   start_station_code    object
#  2   end_date              object
#  3   end_station_code      object
#  4   duration_sec          int64
#  5   is_member             int64
#  6   emplacement_pk_start  float64
#  7   emplacement_pk_end    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.1+ GB

# %% [markdown]
# The date should be datetime type and is_member column should be a boolean, hence let's transform the types of these columns.

# %%
#tranforming the data types in their corresponding types
bixi['start_date'] = pd.to_datetime(bixi['start_date'], format = '%Y-%m-%d')
bixi['end_date'] = pd.to_datetime(bixi['end_date'], format = '%Y-%m-%d')
bixi['is_member'] = bixi['is_member'].astype('bool')

# %% [markdown]
# Now let's investigate once more the data types to self-check our work above!

# %%
bixi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34950766 entries, 0 to 34950765
# Data columns (total 8 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   start_date            datetime64[ns]
#  1   start_station_code    object
#  2   end_date              datetime64[ns]
#  3   end_station_code      object
#  4   duration_sec          int64
#  5   is_member             bool
#  6   emplacement_pk_start  float64
#  7   emplacement_pk_end    float64
# dtypes: bool(1), datetime64[ns](2), float64(2), int64(1), object(2)
# memory usage: 1.9+ GB

# %% [markdown]
# Bingo! Our columns are in the right categories. Let's get a feel of our data by looking at the first five columns of our dataset

# %%
bixi.head()
# Out:
#            start_date start_station_code            end_date end_station_code  \
# 0 2014-04-15 00:01:00               6209 2014-04-15 00:18:00             6436
# 1 2014-04-15 00:01:00               6214 2014-04-15 00:11:00             6248
# 2 2014-04-15 00:01:00               6164 2014-04-15 00:18:00             6216
# 3 2014-04-15 00:01:00               6214 2014-04-15 00:24:00             6082
# 4 2014-04-15 00:02:00               6149 2014-04-15 00:08:00             6265
#
#    duration_sec  is_member  emplacement_pk_start  emplacement_pk_end
# 0          1061       True                   NaN                 NaN
# 1           615       True                   NaN                 NaN
# 2          1031       True                   NaN                 NaN
# 3          1382       True                   NaN                 NaN
# 4           347       True                   NaN                 NaN

# %% [markdown]
# What percentage of null values is in each column? For simplicity-sake, We will drop the column if it has a high percentage
# of null values.

# %%
(bixi.isnull().sum()/bixi.shape[0])*100
# Out:
# start_date               0.000000
# start_station_code       0.000000
# end_date                 0.000000
# end_station_code         0.000000
# duration_sec             0.000000
# is_member                0.000000
# emplacement_pk_start    84.292067
# emplacement_pk_end      84.292067
# dtype: float64

# %% [markdown]
# The last two columns `emplacement_pk_start` and `emplacement_pk_end` have a very high percentage of null values. We will drop
# these variables.

# %%
bixi = bixi.drop(['emplacement_pk_start', 'emplacement_pk_end'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26720/2916693578.py in <module>
# ----> 1 bixi = bixi.drop(['emplacement_pk_start', 'emplacement_pk_end'], axis = 1)
#       2 bixi.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...
